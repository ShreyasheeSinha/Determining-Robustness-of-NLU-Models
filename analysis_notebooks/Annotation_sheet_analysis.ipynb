# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyasheeSinha/Determining-Robustness-of-NLU-Models/blob/main/analysis_notebooks/Annotation_sheet_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook to compute annotation changes from RTE to pRTE.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import json
import numpy as np

# %%
sheet = pd.read_excel("/content/gdrive/MyDrive/paraphraser_work/Gold_label_change/gold_label_change_analysis.xlsx", sheet_name="All")
sheet
# Out:
#          dataset_corpus_id                     s1_para_id  \
# 0      RTE1_test.column_25   RTE1_test.column_s1_25_para1
# 1      RTE1_test.column_49                            NaN
# 2      RTE1_test.column_75                            NaN
# 3      RTE1_test.column_82                            NaN
# 4      RTE1_test.column_82   RTE1_test.column_s1_82_para1
# ...                    ...                            ...
# 1173  RTE3_test.column_787                            NaN
# 1174  RTE3_test.column_788                            NaN
# 1175  RTE3_test.column_796                            NaN
# 1176  RTE3_test.column_798  RTE3_test.column_s1_798_para1
# 1177  RTE3_test.column_800  RTE3_test.column_s1_800_para1
#
#                          s2_para_id  \
# 0                               NaN
# 1      RTE1_test.column_s2_49_para1
# 2      RTE1_test.column_s2_75_para1
# 3      RTE1_test.column_s2_82_para1
# 4                               NaN
# ...                             ...
# ...

# %%
percentage_gold_label_agreement = len(sheet[sheet["Do you agree with column E? (y/n)"] == "y"])/len(sheet["Do you agree with column E? (y/n)"]) * 100
percentage_gold_label_agreement
# Out:
# 98.38709677419355

# %%
percentage_prop_gold_label_agreement = len(sheet[sheet["Do you agree with column H? (y/n)"] == "y"])/len(sheet["Do you agree with column H? (y/n)"]) * 100
percentage_prop_gold_label_agreement
# Out:
# 95.50084889643463

# %%
gold_label_and_prop_label_agreement = len(sheet[sheet["Do you agree with column E? (y/n)"] == sheet["Do you agree with column H? (y/n)"]])/len(sheet["Do you agree with column H? (y/n)"]) * 100
gold_label_and_prop_label_agreement
# Out:
# 95.58573853989813
